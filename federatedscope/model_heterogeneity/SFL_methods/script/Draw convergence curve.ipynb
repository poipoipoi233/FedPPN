# %%
import torch
import numpy as np
import pandas as pd
import json
import matplotlib
import matplotlib.pyplot as plt

# %%
folder_path = '../../result/Convergence_Curve'
client_num = 5

# %%
file_name = f'{folder_path}/FedPPN_cora/client_{client_num}_history_result.json'
# load json
with open(file_name, 'r') as f:
    history_result = json.load(f)

# %%
history_result
# Out:
# {'train_loss': [2373.570119738579,
#   6789.712039470673,
#   6527.906834602356,
#   5066.061192750931,
#   6224.696249008179,
#   4342.81578540802,
#   6213.114896774292,
#   4504.0291249752045,
#   6701.729220151901,
#   2356.77266561985,
#   2782.9845867156982,
#   2177.7588324546814,
#   1894.1188057661057,
#   1502.4658304452896,
#   1197.1822471618652,
#   1020.8728575706482,
#   1070.2036960721016,
#   958.1703961491585,
#   971.7450923919678,
#   934.9919537305832,
#   900.359193444252,
#   792.5410506129265,
#   873.1671657562256,
#   743.020337164402,
#   754.5970366001129,
#   739.6451120972633,
#   769.4852492809296,
#   845.8593742251396,
#   651.3425472974777,
#   679.1334883570671,
#   692.0921151936054,
#   621.9101787507534,
#   508.29342594742775,
#   541.9749948680401,
#   606.3683684170246,
#   554.2688276767731,
#   580.3291780650616,
#   578.1163925230503,
#   614.3462860286236,
#   562.0979391634464,
#   566.0900956094265,
#   543.5403926670551,
# ...

# %%
def load_data(file_path, dataset):
    data = pd.read_csv(file_path, header=None)
    data = data.values
    return data
